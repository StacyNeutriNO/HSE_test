# %%
#импорт библиотек
import pandas as pd
import numpy as np
import textwrap
import os
import plotly.express as px 
import plotly.io as pio
from copy import deepcopy

# %% [markdown]
# # Часть 1

# %%
#считываем файл
data = pd.read_csv('Тестовое задание - tz_data.csv')

# %%
#общая информация о файле
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229 entries, 0 to 228
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area          228 non-null    object
#  1   cluster       228 non-null    float64
#  2   cluster_name  228 non-null    object
#  3   keyword       228 non-null    object
#  4   good (1)      227 non-null    float64
#  5   count         227 non-null    object
#  6   x             228 non-null    float64
#  7   y             228 non-null    object
# dtypes: float64(3), object(5)
# memory usage: 14.4+ KB

# %%
#первые 5 строк
data.head()
# Out:
#           area  cluster cluster_name                     keyword  good (1)  \
# 0  eligibility      0.0    Кластер 0     several animated buried       1.0
# 1  eligibility      0.0    Кластер 0      singles unusual buyers       1.0
# 2  eligibility      0.0    Кластер 0          hawaiian directive       1.0
# 3  eligibility      0.0    Кластер 0           dynamics directly       1.0
# 4  eligibility      1.0    Кластер 1  decision surgeons montreal       1.0
#
#   count          x                   y
# 0  1260   5.772342  12.564796257345005
# 1   866  14.829280  7.8507285727125815
# 2   163  11.381856  3.8981370219558604
# 3  1146   9.980149   6.281427914064545
# 4   823   3.283940    4.39674063521296

# %%
#смотрим пропуски
data.isna().sum()
# Out:
# area            1
# cluster         1
# cluster_name    1
# keyword         1
# good (1)        2
# count           2
# x               1
# y               1
# dtype: int64

# %% [markdown]
# ### 1. В выходной таблице оставляем только нужные колонки

# %%
#удалим столбец
data.drop('good (1)', axis=1, inplace=True)

# %%
data[data['count'].isna()]
# Out:
#            area  cluster cluster_name                keyword count         x  \
# 178  housewives      2.0    Кластер 2  outstanding relations   NaN  1.289158
# 193         NaN      NaN          NaN                    NaN   NaN       NaN
#
#                      y
# 178  6.397514584626231
# 193                NaN

# %%
#удалим полностью пустую строку
data.drop(labels=[193], inplace=True)

# %%
#заполним оставшийся пропуск заглушкой
data['count'].fillna(-1, inplace=True)

# %%
data.isna().sum()
# Out:
# area            0
# cluster         0
# cluster_name    0
# keyword         0
# count           0
# x               0
# y               0
# dtype: int64

# %%
#смотрим уникальные значения в столбце 'count'
#data['count'].value_counts().index.tolist()

# %%
#найдем индексы с "мусорными" значениями в столбце 'count'
idx = data[(data['count']=='N\\A') | (data['count']=='-')].index.tolist()

# %%
#заменим их
data.loc[idx, 'count'] = -1

# %%
#изменим тип данных
data['cluster'] = data['cluster'].astype('int64')
data['count'] = data['count'].astype('int64')

# %%
idx_2 = data[data['y']=='0x414fe002'].index.tolist() #аналогично со столбцом 'y'

# %%
data.loc[idx_2, 'y'] = -1

# %%
data['y'] = data['y'].astype('float64')

# %% [markdown]
# ### 2. Добавляем колонку color

# %%
#функция добавления цвета
#для каждой области цвета различных кластеров будут одинаковыми (но разными внутри области)
def define_color(value):
    if value == 0:
        return 'red'
    elif value == 1:
        return 'green'
    elif value == 2:
        return 'blue'
    elif value == 3:
        return 'orange'

# %%
data['color'] = data.cluster.apply(define_color)

# %%
data
# Out:
#             area  cluster cluster_name                     keyword  count  \
# 0    eligibility        0    Кластер 0     several animated buried   1260
# 1    eligibility        0    Кластер 0      singles unusual buyers    866
# 2    eligibility        0    Кластер 0          hawaiian directive    163
# 3    eligibility        0    Кластер 0           dynamics directly   1146
# 4    eligibility        1    Кластер 1  decision surgeons montreal    823
# ..           ...      ...          ...                         ...    ...
# 224    greetings        2    Кластер 2          disposition layout    279
# 225    greetings        2    Кластер 2            sapphire grounds    335
# 226    greetings        3    Кластер 3     entire ethical speakers   1782
# 227    greetings        3    Кластер 3  courtesy textiles diameter     84
# 228    greetings        3    Кластер 3              comfort rivers   1806
#
#              x          y   color
# 0     5.772342  12.564796     red
# 1    14.829280   7.850729     red
# 2    11.381856   3.898137     red
# 3     9.980149   6.281428     red
# 4     3.283940   4.396741   green
# ..         ...        ...     ...
# 224  10.971214   4.857810    blue
# 225   1.160626   3.642820    blue
# 226   7.985910   6.003699  orange
# 227   0.509490   4.151199  orange
# 228   6.961866   6.435590  orange
#
# [228 rows x 8 columns]

# %% [markdown]
# ### 3. Не должно быть дубликатов слов в одной и той же области (area), но словосочетание может повторяться из area в area

# %%
#уникальные значения каждой области
areas = data.area.value_counts().index.tolist()
areas
# Out:
# ['eligibility',
#  'twisted',
#  'greetings',
#  'capability',
#  'available',
#  'protein',
#  'winner',
#  'locator',
#  'worlds',
#  'ar\\vr',
#  'lithuania',
#  'personnel',
#  'housewives',
#  'dialog',
#  'except']

# %%
#удаляем дубликаты внутри каждой области и создаем новую таблицу df

df = pd.DataFrame()
for area in areas:
    temp = data[data['area']==area].drop_duplicates(subset=['keyword'])
    df = pd.concat([df, temp], ignore_index=True)

# %%
#количество строк сократилось, значит, дубликаты были
df
# Out:
#             area  cluster cluster_name                        keyword  count  \
# 0    eligibility        0    Кластер 0        several animated buried   1260
# 1    eligibility        0    Кластер 0         singles unusual buyers    866
# 2    eligibility        0    Кластер 0             hawaiian directive    163
# 3    eligibility        0    Кластер 0              dynamics directly   1146
# 4    eligibility        1    Кластер 1     decision surgeons montreal    823
# ..           ...      ...          ...                            ...    ...
# 216       except        2    Кластер 2     justin thailand inspection    347
# 217       except        2    Кластер 2  jacksonville tomatoes alberta   1968
# 218       except        3    Кластер 3            missions introduced    987
# 219       except        3    Кластер 3             subscribers member    778
# 220       except        3    Кластер 3            spread presidential   1250
#
#              x          y   color
# 0     5.772342  12.564796     red
# 1    14.829280   7.850729     red
# 2    11.381856   3.898137     red
# 3     9.980149   6.281428     red
# 4     3.283940   4.396741   green
# ..         ...        ...     ...
# 216   9.711229  10.178580    blue
# 217   6.760798  10.922626    blue
# 218   8.042422   5.623459  orange
# 219  10.046830   3.413063  orange
# 220  14.097552   9.872502  orange
#
# [221 rows x 8 columns]

# %% [markdown]
# ### Колонки должны называться именно так, как указано в п.1: area, cluster, cluster_name, keyword, x, y, count, color

# %%
#меняем местами столбцы
df = df.reindex(columns=['area', 'cluster', 'cluster_name', 'keyword',  'x', 'y', 'count', 'color'])
df
# Out:
#             area  cluster cluster_name                        keyword  \
# 0    eligibility        0    Кластер 0        several animated buried
# 1    eligibility        0    Кластер 0         singles unusual buyers
# 2    eligibility        0    Кластер 0             hawaiian directive
# 3    eligibility        0    Кластер 0              dynamics directly
# 4    eligibility        1    Кластер 1     decision surgeons montreal
# ..           ...      ...          ...                            ...
# 216       except        2    Кластер 2     justin thailand inspection
# 217       except        2    Кластер 2  jacksonville tomatoes alberta
# 218       except        3    Кластер 3            missions introduced
# 219       except        3    Кластер 3             subscribers member
# 220       except        3    Кластер 3            spread presidential
#
#              x          y  count   color
# 0     5.772342  12.564796   1260     red
# 1    14.829280   7.850729    866     red
# 2    11.381856   3.898137    163     red
# 3     9.980149   6.281428   1146     red
# 4     3.283940   4.396741    823   green
# ..         ...        ...    ...     ...
# 216   9.711229  10.178580    347    blue
# 217   6.760798  10.922626   1968    blue
# 218   8.042422   5.623459    987  orange
# 219  10.046830   3.413063    778  orange
# 220  14.097552   9.872502   1250  orange
#
# [221 rows x 8 columns]

# %% [markdown]
# ### Сортировка должна происходить по колонкам area, cluster, cluster_name, count (по count значения сортируются в убывающем порядке, в остальных - по возрастающему).

# %%
#cначала отсортируем по 'area', 'cluster', 'cluster_name' в порядке возрастания
df.sort_values(by=['area', 'cluster', 'cluster_name'], inplace=True)

# %%
df.head(14)
# Out:
#       area  cluster cluster_name                                 keyword  \
# 133  ar\vr        0    Кластер 0               written conflict fabulous
# 134  ar\vr        0    Кластер 0                      interfaces neutral
# 135  ar\vr        0    Кластер 0                    reservations linking
# 136  ar\vr        0    Кластер 0                     committees parallel
# 137  ar\vr        1    Кластер 1      postcards looked republic detector
# 138  ar\vr        1    Кластер 1            filling volunteers academics
# 139  ar\vr        1    Кластер 1                         michael tobacco
# 140  ar\vr        1    Кластер 1                       celtic automation
# 141  ar\vr        2    Кластер 2              bangkok mining fascinating
# 142  ar\vr        2    Кластер 2  previously standing languages commands
# 143  ar\vr        2    Кластер 2                enquiries implementation
# 144  ar\vr        3    Кластер 3                        reload athletics
# 145  ar\vr        3    Кластер 3                        several animated
# 146  ar\vr        3    Кластер 3                   announces independent
#
#              x          y  count   color
# 133   2.991167   7.106799   1443     red
# 134  10.443533  13.809915    586     red
# 135  10.195602  12.259496    751     red
# 136   6.735260   3.613983    173     red
# 137  10.474474   6.220012   1397   green
# 138  10.833920   8.652737    773   green
# 139   6.210880  12.721264   1007   green
# 140  12.197275   4.723751    715   green
# 141   5.084247  13.480031    682    blue
# 142  14.668089   8.467136    889    blue
# 143   3.580718   8.089951   1249    blue
# 144   6.020944   4.355278   1189  orange
# 145  11.451222   6.641685    260  orange
# 146   0.381986   7.675412   1669  orange

# %%
#уникальные значения областей в алфавитном порядке
sort_areas = df.area.value_counts().sort_index().index.tolist()
sort_areas
# Out:
# ['ar\\vr',
#  'available',
#  'capability',
#  'dialog',
#  'eligibility',
#  'except',
#  'greetings',
#  'housewives',
#  'lithuania',
#  'locator',
#  'personnel',
#  'protein',
#  'twisted',
#  'winner',
#  'worlds']

# %%
#создаем новую таблицу с сортировкой по столбцу 'count'
sort_df = pd.DataFrame()
for area in sort_areas:
    for cluster in df[df['area']==area].cluster.value_counts().index.tolist():
        sorted = df[(df['area']==area) & (df['cluster']==cluster)].sort_values(by='count', ascending=False)
        sort_df = pd.concat([sort_df, sorted], )

# %%
sort_df.head(14)
# Out:
#       area  cluster cluster_name                                 keyword  \
# 133  ar\vr        0    Кластер 0               written conflict fabulous
# 135  ar\vr        0    Кластер 0                    reservations linking
# 134  ar\vr        0    Кластер 0                      interfaces neutral
# 136  ar\vr        0    Кластер 0                     committees parallel
# 137  ar\vr        1    Кластер 1      postcards looked republic detector
# 139  ar\vr        1    Кластер 1                         michael tobacco
# 138  ar\vr        1    Кластер 1            filling volunteers academics
# 140  ar\vr        1    Кластер 1                       celtic automation
# 143  ar\vr        2    Кластер 2                enquiries implementation
# 142  ar\vr        2    Кластер 2  previously standing languages commands
# 141  ar\vr        2    Кластер 2              bangkok mining fascinating
# 146  ar\vr        3    Кластер 3                   announces independent
# 144  ar\vr        3    Кластер 3                        reload athletics
# 145  ar\vr        3    Кластер 3                        several animated
#
#              x          y  count   color
# 133   2.991167   7.106799   1443     red
# 135  10.195602  12.259496    751     red
# 134  10.443533  13.809915    586     red
# 136   6.735260   3.613983    173     red
# 137  10.474474   6.220012   1397   green
# 139   6.210880  12.721264   1007   green
# 138  10.833920   8.652737    773   green
# 140  12.197275   4.723751    715   green
# 143   3.580718   8.089951   1249    blue
# 142  14.668089   8.467136    889    blue
# 141   5.084247  13.480031    682    blue
# 146   0.381986   7.675412   1669  orange
# 144   6.020944   4.355278   1189  orange
# 145  11.451222   6.641685    260  orange

# %%
#сохраним csv файл
sort_df.to_csv('hse_test_out.csv',index=False)

# %% [markdown]
# # Часть 2

# %%
#создадим копию нашего датафрейма
cp_df = deepcopy(sort_df)

# %%
#функция для разделения длиннных строк
def new_string(string):
    return '<br>'.join(textwrap.wrap(string, width=20))

# %%
cp_df['keyword'] = cp_df['keyword'].apply(new_string)

# %%
cp_df
# Out:
#        area  cluster cluster_name                                keyword  \
# 133   ar\vr        0    Кластер 0           written conflict<br>fabulous
# 135   ar\vr        0    Кластер 0                   reservations linking
# 134   ar\vr        0    Кластер 0                     interfaces neutral
# 136   ar\vr        0    Кластер 0                    committees parallel
# 137   ar\vr        1    Кластер 1  postcards looked<br>republic detector
# ..      ...      ...          ...                                    ...
# 127  worlds        2    Кластер 2                      ringtone parental
# 129  worlds        2    Кластер 2                      recipient traffic
# 132  worlds        3    Кластер 3                      immunology plates
# 130  worlds        3    Кластер 3                        holdings herbal
# 131  worlds        3    Кластер 3                       exchanges castle
#
#              x          y  count   color
# 133   2.991167   7.106799   1443     red
# 135  10.195602  12.259496    751     red
# 134  10.443533  13.809915    586     red
# 136   6.735260   3.613983    173     red
# 137  10.474474   6.220012   1397   green
# ..         ...        ...    ...     ...
# 127  11.723895   4.363994    471    blue
# 129   5.593629   0.553368    236    blue
# 132   2.407028   7.651527   1653  orange
# 130   3.986508  10.906340   1476  orange
# 131   8.082231   6.587933   1097  orange
#
# [221 rows x 8 columns]

# %%
if not os.path.exists("images"):
        os.mkdir("images")

# %%
for area in sort_areas:
    query = cp_df[cp_df['area']==area][['cluster_name','x', 'y','keyword']]
    fig = px.scatter(query, x='x', y='y', color='cluster_name', 
                     color_discrete_map={
                                        'Кластер 0': 'red',
                                        'Кластер 1': 'green',
                                        'Кластер 2': 'blue',
                                        'Кластер 3': 'orange'},
                     text='keyword'
                    )
                     
    fig.update_traces(textposition="bottom center",
                      marker=dict(size=36,
                                  line=dict(width=2,
                                            color='DarkSlateGrey')),
                      textfont=dict(
                                   family="sans-serif",
                                   size=26,
                                   color="black"
                                   )
                     )
                     
    fig.update_layout(
                      xaxis = dict(tickfont=dict(size=30)),
                      yaxis = dict(tickfont=dict(size=30)),
                      plot_bgcolor='rgba(0,0,0,0)',
                      legend=dict(bordercolor="Black",
                                  borderwidth=2,
                                  font=dict(size=30)),
                      height=1200,
                      width=2000,
                      title=dict(text= f'Area: {area}',
                                 xanchor= 'left',
                                 yanchor= 'middle',
                                 font=dict(size=60)
                                 ),
                      font=dict(size=30),
                      margin=dict(l=120, r=120, t=120, b=120)
                     )
    
    fig.update_xaxes(showline=True, linewidth=2, linecolor='black', ticks="outside", ticklen=10)
    fig.update_yaxes(showline=True, linewidth=2, linecolor='black', ticks="outside", ticklen=10)

    fig.add_annotation(dict(
                            font=dict(color='black',size=27),
                            x=0.87,
                            y=-0.078,
                            showarrow=False,
                            text="Источник: система интеллектуального анализа больших данных iFORA",
                            textangle=0,
                            xanchor='center',
                            xref="paper",
                            yref="paper"
                           )
                      )

    pio.write_image(fig, f'images/fig_{area}.png', width=2500, height=1800)
